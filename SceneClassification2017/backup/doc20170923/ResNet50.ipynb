# %%
from PIL import Image

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = './input/ai_challenger_scene_train_20170904/scene_train_images_20170904/000f6d865e7090d7aa1fa1d5d98582bd987bb886.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# Downloading data from https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json
# 24576/35363 [===================>..........] - ETA: 0sPredicted: [('n02412080', 'ram', 0.43712583), ('n02415577', 'bighorn', 0.4133583), ('n02114548', 'white_wolf', 0.035113513)]

# %%
print(model.to_json())
# Out:
# {"class_name": "Model", "config": {"output_layers": [["fc1000", 0, 0]], "name": "resnet50", "layers": [{"class_name": "InputLayer", "config": {"dtype": "float32", "sparse": false, "name": "input_4", "batch_input_shape": [null, 224, 224, 3]}, "name": "input_4", "inbound_nodes": []}, {"class_name": "Conv2D", "config": {"dilation_rate": [1, 1], "kernel_constraint": null, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"mode": "fan_avg", "scale": 1.0, "seed": null, "distribution": "uniform"}}, "bias_constraint": null, "activation": "linear", "padding": "same", "strides": [2, 2], "activity_regularizer": null, "data_format": "channels_last", "filters": 64, "trainable": true, "use_bias": true, "name": "conv1", "kernel_size": [7, 7], "bias_initializer": {"class_name": "Zeros", "config": {}}, "bias_regularizer": null, "kernel_regularizer": null}, "name": "conv1", "inbound_nodes": [[["input_4", 0, 0, {}]]]}, {"class_name": "BatchNormalization", "config": {"momentum": 0.99, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_regularizer": null, "epsilon": 0.001, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "scale": true, "gamma_initializer": {"class_name": "Ones", "config": {}}, "axis": 3, "beta_constraint": null, "gamma_constraint": null, "beta_regularizer": null, "trainable": true, "name": "bn_conv1", "center": true, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}}, "name": "bn_conv1", "inbound_nodes": [[["conv1", 0, 0, {}]]]}, {"class_name": "Activation", "config": {"activation": "relu", "trainable": true, "name": "activation_148"}, "name": "activation_148", "inbound_nodes": [[["bn_conv1", 0, 0, {}]]]}, {"class_name": "MaxPooling2D", "config": {"pool_size": [3, 3], "trainable": true, "name": "max_pooling2d_4", "strides": [2, 2], "padding": "valid", "data_format": "channels_last"}, "name": "max_pooling2d_4", "inbound_nodes": [[["activation_148", 0, 0, {}]]]}, {"class_name": "Conv2D", "config": {"dilation_rate": [1, 1], "kernel_constraint": null, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"mode": "fan_avg", "scale": 1.0, "seed": null, "distribution": "uniform"}}, "bias_constraint": null, "activation": "linear", "padding": "valid", "strides": [1, 1], "activity_regularizer": null, "data_format": "channels_last", "filters": 64, "trainable": true, "use_bias": true, "name": "res2a_branch2a", "kernel_size": [1, 1], "bias_initializer": {"class_name": "Zeros", "config": {}}, "bias_regularizer": null, "kernel_regularizer": null}, "name": "res2a_branch2a", "inbound_nodes": [[["max_pooling2d_4", 0, 0, {}]]]}, {"class_name": "BatchNormalization", "config": {"momentum": 0.99, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_regularizer": null, "epsilon": 0.001, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "scale": true, "gamma_initializer": {"class_name": "Ones", "config": {}}, "axis": 3, "beta_constraint": null, "gamma_constraint": null, "beta_regularizer": null, "trainable": true, "name": "bn2a_branch2a", "center": true, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}}, "name": "bn2a_branch2a", "inbound_nodes": [[["res2a_branch2a", 0, 0, {}]]]}, {"class_name": "Activation", "config": {"activation": "relu", "trainable": true, "name": "activation_149"}, "name": "activation_149", "inbound_nodes": [[["bn2a_branch2a", 0, 0, {}]]]}, {"class_name": "Conv2D", "config": {"dilation_rate": [1, 1], "kernel_constraint": null, "kernel_initializer": {"class_name": "VarianceScaling", "config": {"mode": "fan_avg", "scale": 1.0, "seed": null, "distribution": "uniform"}}, "bias_constraint": null, "activation": "linear", "padding": "same", "strides": [1, 1], "activity_regularizer": null, "data_format": "channels_last", "filters": 64, "trainable": true, "use_bias": true, "name": "res2a_branch2b", "kernel_size": [3, 3], "bias_initializer": {"class_name": "Zeros", "config": {}}, "bias_regularizer": null, "kernel_regu ...
